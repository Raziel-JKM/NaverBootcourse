# %% [markdown]
# <a href="https://colab.research.google.com/github/Raziel-JKM/NaverBootcourse_machine-for-python/blob/main/Pythonic_Code_Lambda_%26_MapReduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lambda & MapReduce
# - 함수처럼 사용가능한 익명함수인 Lambda, Sequence 자료형의 데이터에서 함수를 적용하는 방법인 Map Function 과
# Reduce Function 에 대해서 여러 예제 코드를 이용해 실습하면서 Pythonic Code 를 작성하는 방법
# - Lambda
# - Map Function
# - Reduce Function

# %% [markdown]
# #Lambda
# - 함수 이름 없이, 함수처럼 쓸 수 있는 익명함수
# - 수학의 람다 대수에서 유래함
# f = lambda x, y: x + y
# print(f(1, 4))
# - Python 3부터는 권장하지는 않으나 여전히 많이 쓰임

# %%
f = lambda x, y: x + y

print(f(1, 4))
# Out:
# 5

# %%
f = lambda x: x ** 2

print(f(3))
# Out:
# 9

# %%
f = lambda x: x / 2

print(f(3))

# %%
print((lambda x: x +1)(5))
# Out:
# 6

# %%
def f(x, y):
    return x + y


print(f(1, 4))


f = lambda x, y: x + y
print(f(1, 4))

f = lambda x: x ** 2 # 제곱함수
print(f(3))

f = lambda x: x / 2
print(f(3))

print((lambda x: x + 1)(5))
# Out:
# 5
# 5
# 9
# 1.5
# 6

# %% [markdown]
# #Map function
# - Sequence 자료형 각 element에 동일한 function을 적용함
# ![스크린샷 2021-05-08 오후 8.31.46.png](data:image/png;base64,...)

# %%
x = [1,2,3,4,5]
f = lambda x: x ** 2
print(list(map(f, x)))
# Out:
# [1, 4, 9, 16, 25]

# %%
x = [1,2,3,4,5]
f = lambda x, y: x + y
print(list(map(f, x, x)))
# Out:
# [2, 4, 6, 8, 10]

# %%
# Map

def f(x, y):
    return x + y
f(1, 4)


f = lambda x,y: x+y
f(1, 4)


ex = [1, 2, 3, 4, 5]
f = lambda x: x ** 2
print(list(map(f, ex)))


ex = [1, 2, 3, 4, 5]
f = lambda x, y: x + y
print(list(map(f, ex, ex)))

list(map(
    lambda x: x ** 2 if x % 2 == 0 else x,ex))  #반드시 else 써줘야한다

#python 3에는 list를 꼭 붙여줘야함
ex = [1,2,3,4,5]
print(list(map(lambda x: x+x, ex)))
print((map(lambda x: x+x, ex)))

f = lambda x: x ** 2 #list안붙일경우 for문을 써야한다
print(map(f, ex))
for i in map(f, ex):
    print(i)

result = map(f, ex)
print(result)
print(next(result))

import sys
sys.getsizeof(ex)
sys.getsizeof((map(lambda x: x+x, ex)))
sys.getsizeof(list(map(lambda x: x+x, ex)))

# Reduce
from functools import reduce
print(reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]))


def factorial(n):
    return reduce(
            lambda x, y: x*y, range(1, n+1))


factorial(5)

# %% [markdown]
# #Reduce function
# - map function과 달리 list에 똑같은 함수를 적용해서 통합

# %%
from functools import reduce #
print(reduce(lambda x, y: x+y, [1, 2, 3, 4, 5])) #1+2~>3,3+3~>6,6+4~>10..10+5~>15
# Out:
# 15

# %%
def factorial(n): #!팩토리얼 구할때 , 5!
    return reduce(lambda x, y: x*y, range(1, n+1))
